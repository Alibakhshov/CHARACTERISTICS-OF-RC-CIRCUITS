# %% [markdown]
# <h2 style="font-family:verdana;"><b>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Laboratory work №4</b></h2>
# <p style="font-family:verdana">Instructor: Samat Turdumamatov </p>
# <p style="font-family:verdana">Student: Rauf Alibakhshov </p>
# <p style="font-family:verdana">Date of submission: 1 April, 2022 </p>

# %% [markdown]
# <h2><b>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;EXPERIMENT 4</b></h2>
#
# <p>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<strong>CHARACTERISTICS OF RC CIRCUITS</strong></p>

# %% [markdown]
# <p style="font-family:verdana;"><strong>OBJECTIVE:</strong></p>
# <p style="font-family:verdana;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The objective of the experiment is to learn the timing characteristics of RC
# circuits.</p>
# <p style="font-family:verdana;"><strong>PRELIMINARY WORK:</strong> (Solve the preliminary work and include in your report. You
# can plot the graph with any software you want)</p>

# %% [markdown]
# <p style="font-family:verdana;"><strong>P1:</strong> For the RC circuit shown in Figure 6.1 find and plot CV (t) for charging and
# discharging periods for the component values R1=33KΩ, R2=27KΩ R3=15KΩ and
# C=2200μF. Switch is in position 1 for the time intervals of t is greater that 0 and less than 200 and it is in position 2 for the time intervals of t is greater than 200 and less than 500. Assume capacitor is initially uncharged</p>
# <p style="font-family:verdana;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Charging period (t = 0, 5, 10, 15, 20, 25, 30, 40, 50, 60, 80, 100, 120, 150, 200 sec.)</p>
# <p style="font-family:verdana;">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Discharging period (t = 205, 210, 215, 220, 240, 250, 260, 280, 300, 300,320, 350,
# 400, 450, 500 sec.)</p>

# %%
from IPython import display
display.Image("./Figure 6.1.jpg")

# %%
from IPython import display
display.Image("./P1 solution.jpg")

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
# Creating vectors X and Y
x= np.array([0,5,10,15,20,25,30,40,50,60,80,100,120,150,200,300, 500])
y = 5.357*(1-(2.178)**(-x/21.21))
fig = plt.figure(figsize = (10, 5))

# Create the plot
plt.plot(x, y, 'g:',  label = 'Charging')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
 
plt.title('Charging graph')
plt.legend()
 
# Show the plot
plt.show()

# %% [markdown]
# <p style="font-family:verdana;">P2 Calculate the energy stored in the capacitor given in P1 at charging and discharging
# time intervals. Charging phase is 0-200 sec. Discharging phase is 200-500 sec.</p>

# %%
from IPython import display
display.Image("./P2 solution.jpg")

# %% [markdown]
# <p style="font-family:verdana;"><strong>EQUIPMENT:</strong></p>
# <p style="font-family:verdana;">Digital Multimeter (DMM)</p>
# <p style="font-family:verdana;">Oscilloscope</p>
# <p style="font-family:verdana;">Power Supply</p>
# <p style="font-family:verdana;">Capacitors</p>
# <p style="font-family:verdana;">Resistors</p>
#
# <p style="font-family:verdana;"><strong>EXPERIMENTAL WORK:</strong>(Use the following link for the simulation. Create an
# account before beginning the simulation) </p>

# %% [markdown]
# <p style="font-family:verdana;"><strong>E1:</strong> Set up the circuit in Figure 6.1. Using the same time intervals as in P1 obtain and plot
# the capacitor voltage CV (t) with Time Domain simulation. (The circuit that you will build
# for charging capacitor should look like the one given in Figure 6.2. Also, make sure you
# use time domain simulation and enter desired values. For the charging capacitor it is
# shown in Figure 6.3)</p>

# %%
from IPython import display
display.Image("./Figure 6.2.jpg")

# %%
from IPython import display
display.Image("./Figure 6.3.jpg")

# %%
from IPython import display
display.Image("./circuit in circuitlab.jpg")

# %%
from IPython import display
display.Image("./graph in circuitlab.jpg")

# %% [markdown]
# <strong> CONCLUSION </strong>
# <p style="font-family:verdana;"><strong>C1:</strong>Compare the plots you obtained in P1 and E1. Comment for any discrepancies </p>

# %% [markdown]
# <p style="font-family:verdana;"> The two graphs are identical. The first one was created in a python that show the charging rate of an equation. The second one was obtained in circuit lab website. They both show the same time characteristic of RC circuit </p>

# %% [markdown]
# <p style="font-family:verdana;"><strong>C2:</strong>Obtain the time constant of the circuit from the plots you obtained in E1. Is it same as in P1 or not? Why? </p>

# %% [markdown]
# <p style="font-family:verdana;"> Yes it is the same in both cases. This is because of havig the same total resistor and capacitor in a circuit</p>
